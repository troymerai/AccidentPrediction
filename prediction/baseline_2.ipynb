# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv') 
test = pd.read_csv('test.csv')

# %%
def making_val_table(df):
    '''입력받은 데이터셋의 유효성 검증을 위한 요약 테이블'''
    # dtypes 
    df_dtypes = df.dtypes
    
    # nunique
    df_nunique = df.nunique()
    
    # null_values
    df_nan = df.isna().sum()
    
    val_table = pd.concat([df_dtypes, df_nunique, df_nan], axis=1)
    val_table.columns = ['dtype', 'nunique', 'nan']
        
    return val_table.reset_index()

# %%
# 기상상태, 시군구 데이터의 unique 값이 각각 7vs6, 199vs 192로 다르다
train_info = making_val_table(train)
test_info = making_val_table(test)

pd.merge(left=train_info, right=test_info, on='index', 
         how='left', suffixes=('_train','_test')).set_index('index')
# Out:
#             dtype_train  nunique_train  nan_train dtype_test  nunique_test  \
# index
# ID               object          39609          0     object       10963.0
# 사고일시             object          18057          0     object        5548.0
# 요일               object              7          0     object           7.0
# 기상상태             object              6          0     object           5.0
# 시군구              object            199          0     object         192.0
# 도로형태             object             11          0     object          11.0
# 노면상태             object              6          0     object           6.0
# 사고유형             object              3          0     object           3.0
# 사고유형 - 세부분류      object             14          0        NaN           NaN
# 법규위반             object             11          0        NaN           NaN
# 가해운전자 차종         object             12          0        NaN           NaN
# 가해운전자 성별         object              3          0        NaN           NaN
# 가해운전자 연령         object             89          0        NaN           NaN
# 가해운전자 상해정도       object              6          0        NaN           NaN
# 피해운전자 차종         object             13        991        NaN           NaN
# 피해운전자 성별         object              3        991        NaN           NaN
# 피해운전자 연령         object             97        991        NaN           NaN
# 피해운전자 상해정도       object              6        991        NaN           NaN
# 사망자수              int64              3          0        NaN           NaN
# 중상자수              int64              7          0        NaN           NaN
# 경상자수              int64             18          0        NaN           NaN
# 부상자수              int64              9          0        NaN           NaN
# ECLO              int64             46          0        NaN           NaN
#
#              nan_test
# index
# ID                0.0
# 사고일시              0.0
# 요일                0.0
# 기상상태              0.0
# 시군구               0.0
# 도로형태              0.0
# 노면상태              0.0
# 사고유형              0.0
# 사고유형 - 세부분류       NaN
# 법규위반              NaN
# 가해운전자 차종          NaN
# 가해운전자 성별          NaN
# 가해운전자 연령          NaN
# 가해운전자 상해정도        NaN
# 피해운전자 차종          NaN
# 피해운전자 성별          NaN
# 피해운전자 연령          NaN
# 피해운전자 상해정도        NaN
# 사망자수              NaN
# 중상자수              NaN
# 경상자수              NaN
# 부상자수              NaN
# ECLO              NaN

# %%
# target 변수 지정
y_train = train['ECLO']

# train, test 데이터간 컬럼 동기화 
cols = test.columns
X_train = train[cols]
X_test = test

# %%
def feat_eng(df):
    # datetime 변환
    df['사고일시'] = pd.to_datetime(df['사고일시'])
    
    # 월,일,시 컬럼 생성
    df['월'] = df['사고일시'].dt.month
    df['일'] = df['사고일시'].dt.day
    df['시'] = df['사고일시'].dt.hour
    
    # 불필요 컬럼 제거
    subs = ['ID','사고일시','기상상태','시군구']
    df = df.drop(subs, axis=1)
    
    # one-hot encoding 실시
    df = pd.get_dummies(df)
    
    return df

# %%
X_train_eng = feat_eng(X_train)
X_test_eng = feat_eng(X_test)

# %%
print(f'X_train 데이터 shape : {X_train_eng.shape}')
print(f'y_train 데이터 shape : {y_train.shape}')
print()
print(f'X_test 데이터 shape : {X_test_eng.shape}')
# Out:
# X_train 데이터 shape : (39609, 30)
# y_train 데이터 shape : (39609,)
#
# X_test 데이터 shape : (10963, 30)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train_eng, y_train , test_size=0.2, random_state=42)

# %%
import numpy as np
from autogluon.tabular import TabularDataset, TabularPredictor

# 'ECLO' 열에 대해 결측치를 평균 값으로 대체하고, 무한대 값을 최대값으로 대체
y_train = y_train.replace([np.inf, -np.inf], np.nan)
y_train = y_train.fillna(y_train.mean())

# 타겟 변수를 데이터 프레임에 추가
X_train_eng['ECLO'] = y_train

# 기타 열에 대해 결측치를 평균 값으로 대체하고, 무한대 값을 해당 열의 최대값으로 대체
X_train_eng = X_train_eng.replace([np.inf, -np.inf], np.nan)
X_train_eng = X_train_eng.apply(lambda x: x.fillna(x.mean()), axis=0)

# AutoGluon 학습을 위한 데이터 형태로 변환
train_data = TabularDataset(data=X_train_eng)

predictor = TabularPredictor(label='ECLO').fit(
    train_data=train_data, 
    presets='best_quality', 
    time_limit=60*60
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20231117_021351/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20231117_021351/"
# AutoGluon Version:  0.8.2
# Python Version:     3.8.15
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.5.0: Mon Apr 24 20:53:44 PDT 2023; root:xnu-8796.121.2~5/RELEASE_ARM64_T8103
# Disk Space Avail:   28.26 GB / 245.11 GB (11.5%)
# Train Data Rows:    39609
# Train Data Columns: 30
# Label Column: ECLO
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (74.0, 1.0, 4.73238, 2.8803)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    966.4 MB
# 	Train Data (Original)  Memory Usage: 2.02 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 27 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['노면상태_적설']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('int', []) : 1 | ['노면상태_적설']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', []) : 29 | ['월', '일', '시', '요일_금요일', '요일_목요일', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('int', [])       :  3 | ['월', '일', '시']
# 		('int', ['bool']) : 26 | ['요일_금요일', '요일_목요일', '요일_수요일', '요일_월요일', '요일_일요일', ...]
# 	1.0s = Fit runtime
# 	29 features in original data used to generate 29 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.98 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 1.1s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2398.67s of the 3598.89s of remaining time.
# 	-3.1698	 = Validation score   (-root_mean_squared_error)
# 	0.09s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2398.37s of the 3598.6s of remaining time.
# 	-3.2766	 = Validation score   (-root_mean_squared_error)
# 	0.06s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2398.13s of the 3598.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMXT_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14733, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14733, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2390.25s of the 3590.48s of remaining time.
# 2023-11-17 11:14:00,967	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,972	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,976	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,979	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,985	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,988	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:00,992	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=14761, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=14761, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2382.27s of the 3582.49s of remaining time.
# 2023-11-17 11:14:10,082	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,084	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,091	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,094	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,098	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,105	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:14:10,109	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Reducing model 'n_estimators' from 300 -> 82 due to low memory. Expected memory usage reduced from 54.83% -> 15.0% of available memory...
# 	-3.2083	 = Validation score   (-root_mean_squared_error)
# 	9.34s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2371.98s of the 3572.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8465	 = Validation score   (-root_mean_squared_error)
# 	7.0s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2357.95s of the 3558.18s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 76 due to low memory. Expected memory usage reduced from 58.75% -> 15.0% of available memory...
# 	-3.1811	 = Validation score   (-root_mean_squared_error)
# 	3.54s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2353.64s of the 3553.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8518	 = Validation score   (-root_mean_squared_error)
# 	160.66s	 = Training   runtime
# 	1.32s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2187.21s of the 3387.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8545	 = Validation score   (-root_mean_squared_error)
# 	9.65s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2170.09s of the 3370.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8576	 = Validation score   (-root_mean_squared_error)
# 	169.75s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1992.81s of the 3193.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMLarge_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=15155, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=15155, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Repeating k-fold bagging: 2/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1985.04s of the 3185.26s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-17 11:20:51,546	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,548	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,550	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,554	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,557	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,559	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 11:20:51,561	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-2.8461	 = Validation score   (-root_mean_squared_error)
# 	14.19s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1970.72s of the 3170.95s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8484	 = Validation score   (-root_mean_squared_error)
# 	326.03s	 = Training   runtime
# 	1.82s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1798.17s of the 2998.39s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8528	 = Validation score   (-root_mean_squared_error)
# 	13.91s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1790.85s of the 2991.08s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.855	 = Validation score   (-root_mean_squared_error)
# 	263.65s	 = Training   runtime
# 	0.83s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1693.87s of the 2894.1s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8459	 = Validation score   (-root_mean_squared_error)
# 	18.11s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1686.67s of the 2886.9s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8473	 = Validation score   (-root_mean_squared_error)
# 	409.36s	 = Training   runtime
# 	2.51s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1599.49s of the 2799.72s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8543	 = Validation score   (-root_mean_squared_error)
# 	19.14s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1590.23s of the 2790.46s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8543	 = Validation score   (-root_mean_squared_error)
# 	373.26s	 = Training   runtime
# 	1.31s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1477.3s of the 2677.53s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8459	 = Validation score   (-root_mean_squared_error)
# 	22.52s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1468.85s of the 2669.08s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8468	 = Validation score   (-root_mean_squared_error)
# 	495.74s	 = Training   runtime
# 	3.29s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1378.13s of the 2578.36s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8534	 = Validation score   (-root_mean_squared_error)
# 	25.68s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1368.19s of the 2568.42s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8538	 = Validation score   (-root_mean_squared_error)
# 	465.63s	 = Training   runtime
# 	1.66s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1272.02s of the 2472.25s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8457	 = Validation score   (-root_mean_squared_error)
# 	27.44s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1263.48s of the 2463.71s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8462	 = Validation score   (-root_mean_squared_error)
# 	586.45s	 = Training   runtime
# 	4.04s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1168.87s of the 2369.09s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8529	 = Validation score   (-root_mean_squared_error)
# 	32.13s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1158.53s of the 2358.76s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8541	 = Validation score   (-root_mean_squared_error)
# 	574.41s	 = Training   runtime
# 	2.0s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1046.18s of the 2246.4s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8456	 = Validation score   (-root_mean_squared_error)
# 	31.64s	 = Training   runtime
# 	1.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1037.88s of the 2238.1s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8461	 = Validation score   (-root_mean_squared_error)
# 	678.37s	 = Training   runtime
# 	4.97s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 941.89s of the 2142.12s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8525	 = Validation score   (-root_mean_squared_error)
# 	38.1s	 = Training   runtime
# 	1.05s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 932.04s of the 2132.27s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8539	 = Validation score   (-root_mean_squared_error)
# 	685.72s	 = Training   runtime
# 	2.36s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 817.0s of the 2017.23s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8455	 = Validation score   (-root_mean_squared_error)
# 	36.74s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 807.88s of the 2008.1s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8458	 = Validation score   (-root_mean_squared_error)
# 	776.84s	 = Training   runtime
# 	5.95s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 704.9s of the 1905.13s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8528	 = Validation score   (-root_mean_squared_error)
# 	45.0s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 693.86s of the 1894.09s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8541	 = Validation score   (-root_mean_squared_error)
# 	953.09s	 = Training   runtime
# 	2.71s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 422.6s of the 1622.83s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8455	 = Validation score   (-root_mean_squared_error)
# 	39.74s	 = Training   runtime
# 	1.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 416.5s of the 1616.73s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8457	 = Validation score   (-root_mean_squared_error)
# 	1589.45s	 = Training   runtime
# 	6.85s	 = Validation runtime
# Completed 8/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 800.84s of remaining time.
# 	-2.8446	 = Validation score   (-root_mean_squared_error)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 800.52s of the 800.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMXT_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=17283, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=17283, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 797.11s of the 797.1s of remaining time.
# 2023-11-17 12:00:34,333	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,334	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,339	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,341	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,342	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,343	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:34,346	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBM_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=17300, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=17300, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 794.15s of the 794.13s of remaining time.
# 2023-11-17 12:00:37,372	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,373	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,375	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,375	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,377	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,378	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:00:37,379	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Warning: Reducing model 'n_estimators' from 300 -> 96 due to low memory. Expected memory usage reduced from 46.51% -> 15.0% of available memory...
# 	-2.906	 = Validation score   (-root_mean_squared_error)
# 	8.3s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 785.14s of the 785.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8441	 = Validation score   (-root_mean_squared_error)
# 	4.07s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 778.21s of the 778.2s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 84 due to low memory. Expected memory usage reduced from 53.4% -> 15.0% of available memory...
# 	-2.877	 = Validation score   (-root_mean_squared_error)
# 	2.01s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 775.64s of the 775.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.849	 = Validation score   (-root_mean_squared_error)
# 	196.45s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 576.47s of the 576.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8493	 = Validation score   (-root_mean_squared_error)
# 	5.35s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 567.77s of the 567.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8569	 = Validation score   (-root_mean_squared_error)
# 	82.32s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 481.88s of the 481.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused LightGBMLarge_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=17630, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/__init__.py", line 8, in <module>
#     from .basic import Booster, Dataset, Sequence, register_logger
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 110, in <module>
#     _LIB = _load_lib()
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/basic.py", line 101, in _load_lib
#     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 451, in LoadLibrary
#     return self._dlltype(name)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/ctypes/__init__.py", line 373, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=17630, ip=127.0.0.1)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/core/models/abstract/abstract_model.py", line 829, in fit
#     out = self._fit(**kwargs)
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/tabular/models/lgb/lgb_model.py", line 74, in _fit
#     try_import_lightgbm()  # raise helpful error message if LightGBM isn't installed
#   File "/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/autogluon/common/utils/try_import.py", line 133, in try_import_lightgbm
#     raise ImportError("`import lightgbm` failed. If you are using Mac OSX, " "Please try 'brew install libomp'. Detailed info: {}".format(str(e)))
# ImportError: `import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/itaeyun/opt/anaconda3/envs/dev/lib/python3.8/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Repeating k-fold bagging: 2/20
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 478.02s of the 478.01s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-11-17 12:05:59,274	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,323	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,384	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,386	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,391	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,395	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-11-17 12:05:59,402	ERROR worker.py:399 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-2.8435	 = Validation score   (-root_mean_squared_error)
# 	15.22s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 463.39s of the 463.38s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8465	 = Validation score   (-root_mean_squared_error)
# 	278.71s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 377.58s of the 377.56s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8455	 = Validation score   (-root_mean_squared_error)
# 	12.35s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 367.08s of the 367.07s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-2.8542	 = Validation score   (-root_mean_squared_error)
# 	180.22s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Completed 2/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 265.37s of remaining time.
# 	-2.8284	 = Validation score   (-root_mean_squared_error)
# 	0.34s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3335.0s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20231117_021351/")

# %%
# 예측하기
pred_y = predictor.predict(X_test_eng)

# %%
sample_submission = pd.read_csv("sample_submission.csv")

baseline_submission = sample_submission.copy()
baseline_submission['ECLO'] = pred_y
baseline_submission
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  4.348880
# 1      ACCIDENT_39610  4.108166
# 2      ACCIDENT_39611  5.254338
# 3      ACCIDENT_39612  5.115234
# 4      ACCIDENT_39613  5.009536
# ...               ...       ...
# 10958  ACCIDENT_50567  6.624053
# 10959  ACCIDENT_50568  5.320106
# 10960  ACCIDENT_50569  4.731536
# 10961  ACCIDENT_50570  4.807998
# 10962  ACCIDENT_50571  5.138278
#
# [10963 rows x 2 columns]

# %%
baseline_submission.to_csv('fourth_submit.csv', index=False)

# %%
# csv 파일을 읽어옵니다.
df = pd.read_csv('third_submit.csv')

# 빈 값을 0으로 채웁니다.
df = df.fillna(0)

# 변경된 데이터를 다시 csv 파일로 저장합니다.
df.to_csv('fourth_submit.csv', index=False)
